# %%
from src.data import get_questions_df

question_df = get_questions_df()
# Out:
# /home/lambertbruyas/git_perso/gpt-pursuit/data-acquisition/src/data.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Category"] = datasets[sheet_name]["Category"+suffix]
# /home/lambertbruyas/git_perso/gpt-pursuit/data-acquisition/src/data.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["Category"] = datasets[sheet_name]["Category"+suffix]
# /home/lambertbruyas/git_perso/gpt-pursuit/data-acquisition/src/data.py:29: SettingWithCopyWarning:
# ...

# %%
import os
question_df.to_csv(os.path.join("data", "raw", "questions.csv"), index=False)
